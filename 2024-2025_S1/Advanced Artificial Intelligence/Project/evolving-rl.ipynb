# %%
# !git clone https://github.com/GadGadGad/brain_autorl

# %%
import os
os.chdir('/kaggle/working/brain_autorl')

# %% [markdown]
# # Set-up conda

# %%
# !conda create -n evolving-rl python=3.8 -y #Test with python=3.8 which works, maybe 3.6->3.9 will work?

# %%
# !conda info --envs
# !source /opt/conda/bin/activate evolving-rl

# %%
import os
os.environ['LD_LIBRARY_PATH'] = '/opt/conda/envs/evolving-rl/lib:' + os.environ.get('LD_LIBRARY_PATH', '')
# !echo $LD_LIBRARY_PATH

# %%
# !/opt/conda/envs/evolving-rl/bin/python3 --version
# !echo 'print("Hello, World!")' > test.py
# !/opt/conda/envs/evolving-rl/bin/python3 test.py

# %%
# !sudo rm /opt/conda/bin/python3
# !sudo ln -sf /opt/conda/envs/evolving-rl/bin/python3 /opt/conda/bin/python3
# !sudo rm /opt/conda/bin/python3.10
# !sudo ln -sf /opt/conda/envs/evolving-rl/bin/python3 /opt/conda/bin/python3.10
# !sudo rm /opt/conda/bin/python
# !sudo ln -s /opt/conda/envs/evolving-rl/bin/python3 /opt/conda/bin/python

# %% [markdown]
# ## Run code

# %%
import os
os.chdir('/kaggle/working/brain_autorl/evolving_rl')

# %%
# !/opt/conda/envs/evolving-rl/bin/pip install -r requirements.txt

# %%
# !/opt/conda/envs/evolving-rl/bin/python3 run_search.py
